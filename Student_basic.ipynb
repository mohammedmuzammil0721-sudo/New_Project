# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('C:\\Users\\D.MD.MUZAMMIL\\OneDrive\Desktop\\Book1.csv')
df
# Out:
#    NO      NAMES  MARKS
# 0    1     MUZZU     99
# 1    2    MASTAN     66
# 2    3    ASHFAQ     77
# 3    4  MUZAMMIL     65
# 4    5      ARIF     75
# 5    6    LOKESH     22
# 6    7  KHOWSHIK     44
# 7    8      RAJU     77
# 8    9      RAMU     99
# 9   10      SOMU     66

# %%
df.max()
# Out:
# NO         10
# NAMES    SOMU
# MARKS      99
# dtype: object

# %%
df.min()
# Out:
# NO          1
# NAMES    ARIF
# MARKS      22
# dtype: object

# %%
df.MARKS
# Out:
# 0    99
# 1    66
# 2    77
# 3    65
# 4    75
# 5    22
# 6    44
# 7    77
# 8    99
# 9    66
# Name: MARKS, dtype: int64

# %%
df['Science']=[88,44,22,77,44,86,24,97,15,66]
df['maths']=[44,63,12,43,76,13,86,95,21,87]
df['english']=[88,53,12,54,93,12,54,76,45,67]
df
# Out:
#    NO      NAMES  MARKS  Science  maths  english
# 0    1     MUZZU     99       88     44       88
# 1    2    MASTAN     66       44     63       53
# 2    3    ASHFAQ     77       22     12       12
# 3    4  MUZAMMIL     65       77     43       54
# 4    5      ARIF     75       44     76       93
# 5    6    LOKESH     22       86     13       12
# 6    7  KHOWSHIK     44       24     86       54
# 7    8      RAJU     77       97     95       76
# 8    9      RAMU     99       15     21       45
# 9   10      SOMU     66       66     87       67

# %%
df.drop(2)
# Out:
#    NO      NAMES  MARKS  Science  maths  english
# 0    1     MUZZU     99       88     44       88
# 1    2    MASTAN     66       44     63       53
# 3    4  MUZAMMIL     65       77     43       54
# 4    5      ARIF     75       44     76       93
# 5    6    LOKESH     22       86     13       12
# 6    7  KHOWSHIK     44       24     86       54
# 7    8      RAJU     77       97     95       76
# 8    9      RAMU     99       15     21       45
# 9   10      SOMU     66       66     87       67

# %%
df = df.drop(columns=['MARKS'])
df
# Out:
#    NO      NAMES  Science  maths  english
# 0    1     MUZZU       88     44       88
# 1    2    MASTAN       44     63       53
# 2    3    ASHFAQ       22     12       12
# 3    4  MUZAMMIL       77     43       54
# 4    5      ARIF       44     76       93
# 5    6    LOKESH       86     13       12
# 6    7  KHOWSHIK       24     86       54
# 7    8      RAJU       97     95       76
# 8    9      RAMU       15     21       45
# 9   10      SOMU       66     87       67

# %%
df['Total']=df['Science']+df['maths']+df['english']
df
# Out:
#    NO      NAMES  Science  maths  english  Total
# 0    1     MUZZU       88     44       88    220
# 1    2    MASTAN       44     63       53    160
# 2    3    ASHFAQ       22     12       12     46
# 3    4  MUZAMMIL       77     43       54    174
# 4    5      ARIF       44     76       93    213
# 5    6    LOKESH       86     13       12    111
# 6    7  KHOWSHIK       24     86       54    164
# 7    8      RAJU       97     95       76    268
# 8    9      RAMU       15     21       45     81
# 9   10      SOMU       66     87       67    220

# %%
df['Avarage']=df[['Science','maths','english']].mean(axis=1)
df
# Out:
#    NO      NAMES  Science  maths  english  Total    Avarage
# 0    1     MUZZU       88     44       88    220  73.333333
# 1    2    MASTAN       44     63       53    160  53.333333
# 2    3    ASHFAQ       22     12       12     46  15.333333
# 3    4  MUZAMMIL       77     43       54    174  58.000000
# 4    5      ARIF       44     76       93    213  71.000000
# 5    6    LOKESH       86     13       12    111  37.000000
# 6    7  KHOWSHIK       24     86       54    164  54.666667
# 7    8      RAJU       97     95       76    268  89.333333
# 8    9      RAMU       15     21       45     81  27.000000
# 9   10      SOMU       66     87       67    220  73.333333

# %%
df.max()
# Out:
# NO                10
# NAMES           SOMU
# Science           97
# maths             95
# english           93
# Total            268
# Avarage    89.333333
# dtype: object

# %%
df.min()
# Out:
# NO                 1
# NAMES           ARIF
# Science           15
# maths             12
# english           12
# Total             46
# Avarage    15.333333
# dtype: object

# %%
import seaborn as sns
plt.figure(figsize=(14, 6))
sns.barplot(x='NAMES',y='Avarage',data=df)
plt.show()

# %%
import seaborn as sns
plt.xticks(fontsize=8)
sns.barplot(x='NAMES',y='Avarage',data=df)
plt.show()

# %%
import seaborn as sns
plt.xticks(rotation=45, ha='right', fontsize=8)
sns.barplot(x='NAMES',y='Avarage',data=df)
plt.show()

# %%
import seaborn as sns
plt.xticks(rotation=45, ha='right', fontsize=8)
sns.boxplot(x='NAMES',y='Avarage',data=df)
plt.show()
